# %%
import pandas as pd
import geopandas as gpd 
import matplotlib.pyplot as plt 
import contextily as ctx
import numpy as np
import quilt3
from geopandas_view import view

# %%
gpd.read_file?
# Out:
# Signature: gpd.read_file(filename, bbox=None, mask=None, rows=None, **kwargs)
# Docstring:
# Returns a GeoDataFrame from a file or URL.
#
# .. versionadded:: 0.7.0 mask, rows
#
# Parameters
# ----------
# filename : str, path object or file-like object
#     Either the absolute or relative path to the file or URL to
#     be opened, or any object with a read() method (such as an open file
#     or StringIO)
# bbox : tuple | GeoDataFrame or GeoSeries | shapely Geometry, default None
#     Filter features by given bounding box, GeoSeries, GeoDataFrame or a
#     shapely geometry. CRS mis-matches are resolved if given a GeoSeries
#     or GeoDataFrame. Cannot be used with mask.
# mask : dict | GeoDataFrame or GeoSeries | shapely Geometry, default None
#     Filter for features that intersect with the given dict-like geojson
#     geometry, GeoSeries, GeoDataFrame or shapely geometry.
#     CRS mis-matches are resolved if given a GeoSeries or GeoDataFrame.
# ...

# %%
SEDA = pd.read_csv("https://stacks.stanford.edu/file/druid:db586ns4974/seda_cov_school_poolyr_4.0.csv")

# %%
SEDA
# Out:
#              sedasch  year                     schnam      schcity  sedalea  \
# 0        10000500870  2009  Albertville Middle School  ALBERTVILLE   100005
# 1        10000500870  2010  Albertville Middle School  ALBERTVILLE   100005
# 2        10000500870  2011  Albertville Middle School  ALBERTVILLE   100005
# 3        10000500870  2012  Albertville Middle School  ALBERTVILLE   100005
# 4        10000500870  2013  Albertville Middle School  ALBERTVILLE   100005
# ...              ...   ...                        ...          ...      ...
# 746818  720003002084  2014       NEMESIO R. CANALES I     SAN JUAN  7200030
# 746819  720003002084  2015       NEMESIO R. CANALES I     SAN JUAN  7200030
# 746820  720003002084  2016       NEMESIO R. CANALES I     SAN JUAN  7200030
# 746821  720003002084  2017       NEMESIO R. CANALES I     SAN JUAN  7200030
# 746822  720003002084  2018       NEMESIO R. CANALES I     SAN JUAN  7200030
#
# ...

# %%
type(SEDA)
# Out:
# pandas.core.frame.DataFrame

# %%
SEDA.shape
# Out:
# (746823, 31)

# %%
#CONTAINS 31 COLUMNS

# %%
SEDA.columns
# Out:
# Index(['sedasch', 'year', 'schnam', 'schcity', 'sedalea', 'fips', 'stateabb',
#        'type', 'level', 'mingrd', 'maxgrd', 'charter', 'magnet', 'urbanicity',
#        'totenrl', 'perwht', 'perind', 'perasn', 'perhsp', 'perblk', 'perfl',
#        'perrl', 'perfrl', 'perecd', 'locale', 'lep', 'disab_tot',
#        'disab_tot_idea', 'gifted_tot', 'sch_sped', 'avgrdall'],
#       dtype='object')

# %%
SEDA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 746823 entries, 0 to 746822
# Data columns (total 31 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   sedasch         746823 non-null  int64
#  1   year            746823 non-null  int64
#  2   schnam          746823 non-null  object
#  3   schcity         746810 non-null  object
#  4   sedalea         746823 non-null  int64
#  5   fips            746823 non-null  int64
#  6   stateabb        746823 non-null  object
#  7   type            746810 non-null  object
#  8   level           746609 non-null  object
#  9   mingrd          740278 non-null  float64
#  10  maxgrd          740278 non-null  float64
#  11  charter         746810 non-null  float64
#  12  magnet          746810 non-null  float64
#  13  urbanicity      746483 non-null  object
#  14  totenrl         746823 non-null  float64
#  15  perwht          746823 non-null  float64
# ...

# %%
SEDA
# Out:
#              sedasch  year                     schnam      schcity  sedalea  \
# 0        10000500870  2009  Albertville Middle School  ALBERTVILLE   100005
# 1        10000500870  2010  Albertville Middle School  ALBERTVILLE   100005
# 2        10000500870  2011  Albertville Middle School  ALBERTVILLE   100005
# 3        10000500870  2012  Albertville Middle School  ALBERTVILLE   100005
# 4        10000500870  2013  Albertville Middle School  ALBERTVILLE   100005
# ...              ...   ...                        ...          ...      ...
# 746818  720003002084  2014       NEMESIO R. CANALES I     SAN JUAN  7200030
# 746819  720003002084  2015       NEMESIO R. CANALES I     SAN JUAN  7200030
# 746820  720003002084  2016       NEMESIO R. CANALES I     SAN JUAN  7200030
# 746821  720003002084  2017       NEMESIO R. CANALES I     SAN JUAN  7200030
# 746822  720003002084  2018       NEMESIO R. CANALES I     SAN JUAN  7200030
#
# ...

# %%
seda_2018yr = SEDA[SEDA.year == 2018]

# %%
seda_2018yr
# Out:
#              sedasch  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# 746792  720003002079  2018             SEVERO E. COLBERG RAMIREZ    CABO ROJO
# 746802  720003002082  2018             INTERMEDIA JUAN SERRALLES        PONCE
# 746812  720003002083  2018                       MARTIN GONZALEZ     CAROLINA
# 746822  720003002084  2018                  NEMESIO R. CANALES I     SAN JUAN
#
# ...

# %%
seda_2018yr.shape
# Out:
# (73345, 31)

# %%
seda_2018yr_riv = seda_2018yr[seda_2018yr['sedasch']=='06065']

# %%
seda_2018yr_riv
# Out:
# Empty DataFrame
# Columns: [sedasch, year, schnam, schcity, sedalea, fips, stateabb, type, level, mingrd, maxgrd, charter, magnet, urbanicity, totenrl, perwht, perind, perasn, perhsp, perblk, perfl, perrl, perfrl, perecd, locale, lep, disab_tot, disab_tot_idea, gifted_tot, sch_sped, avgrdall]
# Index: []
#
# [0 rows x 31 columns]

# %%
seda_2018yr
# Out:
#              sedasch  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# 746792  720003002079  2018             SEVERO E. COLBERG RAMIREZ    CABO ROJO
# 746802  720003002082  2018             INTERMEDIA JUAN SERRALLES        PONCE
# 746812  720003002083  2018                       MARTIN GONZALEZ     CAROLINA
# 746822  720003002084  2018                  NEMESIO R. CANALES I     SAN JUAN
#
# ...

# %%
seda_2018yr_riv
# Out:
# Empty DataFrame
# Columns: [sedasch, year, schnam, schcity, sedalea, fips, stateabb, type, level, mingrd, maxgrd, charter, magnet, urbanicity, totenrl, perwht, perind, perasn, perhsp, perblk, perfl, perrl, perfrl, perecd, locale, lep, disab_tot, disab_tot_idea, gifted_tot, sch_sped, avgrdall]
# Index: []
#
# [0 rows x 31 columns]

# %%
seda_2018yr
# Out:
#              sedasch  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# 746792  720003002079  2018             SEVERO E. COLBERG RAMIREZ    CABO ROJO
# 746802  720003002082  2018             INTERMEDIA JUAN SERRALLES        PONCE
# 746812  720003002083  2018                       MARTIN GONZALEZ     CAROLINA
# 746822  720003002084  2018                  NEMESIO R. CANALES I     SAN JUAN
#
# ...

# %%
seda_2018yr
# Out:
#              sedasch  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# 746792  720003002079  2018             SEVERO E. COLBERG RAMIREZ    CABO ROJO
# 746802  720003002082  2018             INTERMEDIA JUAN SERRALLES        PONCE
# 746812  720003002083  2018                       MARTIN GONZALEZ     CAROLINA
# 746822  720003002084  2018                  NEMESIO R. CANALES I     SAN JUAN
#
# ...

# %%
seda_2018yr_riverside = seda_2018yr[seda_2018yr['sedasch']=='06065']

# %%
seda_2018yr_riverside
# Out:
# Empty DataFrame
# Columns: [sedasch, year, schnam, schcity, sedalea, fips, stateabb, type, level, mingrd, maxgrd, charter, magnet, urbanicity, totenrl, perwht, perind, perasn, perhsp, perblk, perfl, perrl, perfrl, perecd, locale, lep, disab_tot, disab_tot_idea, gifted_tot, sch_sped, avgrdall]
# Index: []
#
# [0 rows x 31 columns]

# %%
seda_2018yr
# Out:
#              sedasch  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# 746792  720003002079  2018             SEVERO E. COLBERG RAMIREZ    CABO ROJO
# 746802  720003002082  2018             INTERMEDIA JUAN SERRALLES        PONCE
# 746812  720003002083  2018                       MARTIN GONZALEZ     CAROLINA
# 746822  720003002084  2018                  NEMESIO R. CANALES I     SAN JUAN
#
# ...

# %%
b = quilt3.Bucket("s3://spatial-ucr")
b.fetch("epa/ejscreen/ejscreen_2020.parquet", "./ejscreen_2020.parquet"), 
ej = pd.read_parquet('ejscreen_2020.parquet')

ej
# Out:
# 100%|██████████| 146M/146M [00:05<00:00, 27.8MB/s]
#         OBJECTID            ID  ACSTOTPOP ACSIPOVBAS  ACSEDUCBAS  ACSTOTHH  \
# 0              1  010010201001        636        636         418       294
# 1              2  010010201002       1287       1287         885       471
# 2              3  010010202001        810        802         568       322
# 3              4  010010202002       1218       1016         875       397
# 4              5  010010203001       2641       2641        1849       948
# ...          ...           ...        ...        ...         ...       ...
# 220328    220329  721537506011        699        699         511       250
# 220329    220330  721537506012       2432       2432        1555       670
# 220330    220331  721537506013        976        976         552       231
# 220331    220332  721537506021       1707       1689        1481       573
# 220332    220333  721537506022        804        804         645       219
#
# ...

# %%
ej.rename(columns = {'ID' : 'GEOID'}, inplace = True)

ej
# Out:
#         OBJECTID         GEOID  ACSTOTPOP ACSIPOVBAS  ACSEDUCBAS  ACSTOTHH  \
# 0              1  010010201001        636        636         418       294
# 1              2  010010201002       1287       1287         885       471
# 2              3  010010202001        810        802         568       322
# 3              4  010010202002       1218       1016         875       397
# 4              5  010010203001       2641       2641        1849       948
# ...          ...           ...        ...        ...         ...       ...
# 220328    220329  721537506011        699        699         511       250
# 220329    220330  721537506012       2432       2432        1555       670
# 220330    220331  721537506013        976        976         552       231
# 220331    220332  721537506021       1707       1689        1481       573
# 220332    220333  721537506022        804        804         645       219
#
# ...

# %%
seda_2018yr
# Out:
#              sedasch  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# 746792  720003002079  2018             SEVERO E. COLBERG RAMIREZ    CABO ROJO
# 746802  720003002082  2018             INTERMEDIA JUAN SERRALLES        PONCE
# 746812  720003002083  2018                       MARTIN GONZALEZ     CAROLINA
# 746822  720003002084  2018                  NEMESIO R. CANALES I     SAN JUAN
#
# ...

# %%
seda_2018yr.rename(columns = {'sedasch' : ' GEOID'}, inplace = True)

seda_2018yr
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/frame.py:4449: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                GEOID  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# ...

# %%
acs_data = gpd.read_parquet('s3://spatial-ucr/census/acs/acs_2018_bg.parquet')

acs_data
# Out:
#               n_persons_under_18  n_persons_over_60  n_persons_over_75  \
# GEOID
# 020130001003               287.0              213.0               26.0
# 020160001001               175.0              157.0               25.0
# 020160002001               320.0              224.0               21.0
# 020160002002               468.0              335.0               29.0
# 020200001011                75.0               79.0               37.0
# ...                          ...                ...                ...
# 560419753004               100.0              179.0               36.0
# 560419753005               310.0              198.0               68.0
# 560419753006               344.0              213.0               21.0
# 560419754001               153.0               73.0               23.0
# 560419754002               354.0              193.0               83.0
#
#               n_persons_over_15  n_married  n_widowed_divorced  \
# GEOID
# ...

# %%
schools = gpd.read_parquet('s3://spatial-ucr/nces/schools/schools_1718.parquet')

# %%
schools
# Out:
#              NCESSCH                                  NAME OPSTFIPS  \
# 0       010000500870             Albertville Middle School       01
# 1       010000500871               Albertville High School       01
# 2       010000500879               Evans Elementary School       01
# 3       010000500889         Albertville Elementary School       01
# 4       010000501616   Big Spring Lake Kindergarten School       01
# ...              ...                                   ...      ...
# 102332  780003000025  GLADYS A. ABRAHAM  ELEMENTARY SCHOOL       78
# 102333  780003000026       ULLA F MULLER ELEMENTARY SCHOOL       78
# 102334  780003000027       YVONNE BOWSKY ELEMENTARY SCHOOL       78
# 102335  780003000033            CANCRYN JUNIOR HIGH SCHOOL       78
# 102336  780003000034          BERTHA BOSCHULTE JUNIOR HIGH       78
#
#                            STREET          CITY STATE    ZIP STFIP   CNTY  \
# 0               600 E Alabama Ave   Albertville    AL  35950    01  01095
# ...

# %%
schools.rename(columns = {'NCESSCH' : ' GEOID'}, inplace = True)

schools
# Out:
#                GEOID                                  NAME OPSTFIPS  \
# 0       010000500870             Albertville Middle School       01
# 1       010000500871               Albertville High School       01
# 2       010000500879               Evans Elementary School       01
# 3       010000500889         Albertville Elementary School       01
# 4       010000501616   Big Spring Lake Kindergarten School       01
# ...              ...                                   ...      ...
# 102332  780003000025  GLADYS A. ABRAHAM  ELEMENTARY SCHOOL       78
# 102333  780003000026       ULLA F MULLER ELEMENTARY SCHOOL       78
# 102334  780003000027       YVONNE BOWSKY ELEMENTARY SCHOOL       78
# 102335  780003000033            CANCRYN JUNIOR HIGH SCHOOL       78
# 102336  780003000034          BERTHA BOSCHULTE JUNIOR HIGH       78
#
#                            STREET          CITY STATE    ZIP STFIP   CNTY  \
# 0               600 E Alabama Ave   Albertville    AL  35950    01  01095
# ...

# %%
seda_2018yr
# Out:
#                GEOID  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# 746792  720003002079  2018             SEVERO E. COLBERG RAMIREZ    CABO ROJO
# 746802  720003002082  2018             INTERMEDIA JUAN SERRALLES        PONCE
# 746812  720003002083  2018                       MARTIN GONZALEZ     CAROLINA
# 746822  720003002084  2018                  NEMESIO R. CANALES I     SAN JUAN
#
# ...

# %%
seda_2018yr = seda_2018yr[seda_2018yr['GEOID']=='06065']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GEOID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-a7cfea7a10f7> in <module>
# ...

# %%
schools = schools[schools['CNTY']=='06065']

# %%
schools
# Out:
#                GEOID                                      NAME OPSTFIPS  \
# 5576    060000710348  California School for the Deaf-Riverside       06
# 5727    060002702451                  Tuscany Hills Elementary       06
# 5728    060002702452                  Donald Graham Elementary       06
# 5729    060002705011                     David A. Brown Middle       06
# 5730    060002707605                William Collier Elementary       06
# ...              ...                                       ...      ...
# 15979   069113512749                         Val Verde Academy       06
# 15980   069113513435                     El Potrero Pre-School       06
# 15981   069113513992                         Orange Vista High       06
# 100864  590010500138                Sherman Indian High School       59
# 100956  590019700136                               Noli School       59
#
#                      STREET           CITY STATE    ZIP STFIP   CNTY  \
# ...

# %%
acs_data
# Out:
#               n_persons_under_18  n_persons_over_60  n_persons_over_75  \
# GEOID
# 020130001003               287.0              213.0               26.0
# 020160001001               175.0              157.0               25.0
# 020160002001               320.0              224.0               21.0
# 020160002002               468.0              335.0               29.0
# 020200001011                75.0               79.0               37.0
# ...                          ...                ...                ...
# 560419753004               100.0              179.0               36.0
# 560419753005               310.0              198.0               68.0
# 560419753006               344.0              213.0               21.0
# 560419754001               153.0               73.0               23.0
# 560419754002               354.0              193.0               83.0
#
#               n_persons_over_15  n_married  n_widowed_divorced  \
# GEOID
# ...

# %%
acs_data = acs_data[acs_data['GEOID']=='06065']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'GEOID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-f914f4ba08cd> in <module>
# ...

# %%
schools = schools[schools['CNTY']=='06065']

# %%
ej
# Out:
#         OBJECTID         GEOID  ACSTOTPOP ACSIPOVBAS  ACSEDUCBAS  ACSTOTHH  \
# 0              1  010010201001        636        636         418       294
# 1              2  010010201002       1287       1287         885       471
# 2              3  010010202001        810        802         568       322
# 3              4  010010202002       1218       1016         875       397
# 4              5  010010203001       2641       2641        1849       948
# ...          ...           ...        ...        ...         ...       ...
# 220328    220329  721537506011        699        699         511       250
# 220329    220330  721537506012       2432       2432        1555       670
# 220330    220331  721537506013        976        976         552       231
# 220331    220332  721537506021       1707       1689        1481       573
# 220332    220333  721537506022        804        804         645       219
#
# ...

# %%
b = quilt3.Bucket("s3://spatial-ucr")
b.fetch("epa/ejscreen/ejscreen_2020.parquet", "./ejscreen_2020.parquet"), 
ej = pd.read_parquet('ejscreen_2020.parquet')

ej
# Out:
# 100%|██████████| 146M/146M [00:04<00:00, 29.5MB/s]
#         OBJECTID            ID  ACSTOTPOP ACSIPOVBAS  ACSEDUCBAS  ACSTOTHH  \
# 0              1  010010201001        636        636         418       294
# 1              2  010010201002       1287       1287         885       471
# 2              3  010010202001        810        802         568       322
# 3              4  010010202002       1218       1016         875       397
# 4              5  010010203001       2641       2641        1849       948
# ...          ...           ...        ...        ...         ...       ...
# 220328    220329  721537506011        699        699         511       250
# 220329    220330  721537506012       2432       2432        1555       670
# 220330    220331  721537506013        976        976         552       231
# 220331    220332  721537506021       1707       1689        1481       573
# 220332    220333  721537506022        804        804         645       219
#
# ...

# %%
ej.rename(columns = {'ID' : 'GEOID'}, inplace = True)

ej
# Out:
#         OBJECTID         GEOID  ACSTOTPOP ACSIPOVBAS  ACSEDUCBAS  ACSTOTHH  \
# 0              1  010010201001        636        636         418       294
# 1              2  010010201002       1287       1287         885       471
# 2              3  010010202001        810        802         568       322
# 3              4  010010202002       1218       1016         875       397
# 4              5  010010203001       2641       2641        1849       948
# ...          ...           ...        ...        ...         ...       ...
# 220328    220329  721537506011        699        699         511       250
# 220329    220330  721537506012       2432       2432        1555       670
# 220330    220331  721537506013        976        976         552       231
# 220331    220332  721537506021       1707       1689        1481       573
# 220332    220333  721537506022        804        804         645       219
#
# ...

# %%
ej
# Out:
#         OBJECTID         GEOID  ACSTOTPOP ACSIPOVBAS  ACSEDUCBAS  ACSTOTHH  \
# 0              1  010010201001        636        636         418       294
# 1              2  010010201002       1287       1287         885       471
# 2              3  010010202001        810        802         568       322
# 3              4  010010202002       1218       1016         875       397
# 4              5  010010203001       2641       2641        1849       948
# ...          ...           ...        ...        ...         ...       ...
# 220328    220329  721537506011        699        699         511       250
# 220329    220330  721537506012       2432       2432        1555       670
# 220330    220331  721537506013        976        976         552       231
# 220331    220332  721537506021       1707       1689        1481       573
# 220332    220333  721537506022        804        804         645       219
#
# ...

# %%
seda_2018yr
# Out:
#                GEOID  year                                schnam      schcity  \
# 9        10000500870  2018             Albertville Middle School  Albertville
# 19       10000500879  2018               Evans Elementary School  Albertville
# 29       10000500889  2018         Albertville Elementary School  Albertville
# 39       10000600193  2018          Kate Duncan Smith DAR Middle        Grant
# 49       10000600872  2018                    Asbury High School  Albertville
# ...              ...   ...                                   ...          ...
# 746782  720003002078  2018  ALEJANDRO JR CRUZ (GALATEO PARCELAS)     TOA ALTA
# 746792  720003002079  2018             SEVERO E. COLBERG RAMIREZ    CABO ROJO
# 746802  720003002082  2018             INTERMEDIA JUAN SERRALLES        PONCE
# 746812  720003002083  2018                       MARTIN GONZALEZ     CAROLINA
# 746822  720003002084  2018                  NEMESIO R. CANALES I     SAN JUAN
#
# ...

# %%
acs_data
# Out:
#               n_persons_under_18  n_persons_over_60  n_persons_over_75  \
# GEOID
# 020130001003               287.0              213.0               26.0
# 020160001001               175.0              157.0               25.0
# 020160002001               320.0              224.0               21.0
# 020160002002               468.0              335.0               29.0
# 020200001011                75.0               79.0               37.0
# ...                          ...                ...                ...
# 560419753004               100.0              179.0               36.0
# 560419753005               310.0              198.0               68.0
# 560419753006               344.0              213.0               21.0
# 560419754001               153.0               73.0               23.0
# 560419754002               354.0              193.0               83.0
#
#               n_persons_over_15  n_married  n_widowed_divorced  \
# GEOID
# ...

# %%
schools
# Out:
#                GEOID                                      NAME OPSTFIPS  \
# 5576    060000710348  California School for the Deaf-Riverside       06
# 5727    060002702451                  Tuscany Hills Elementary       06
# 5728    060002702452                  Donald Graham Elementary       06
# 5729    060002705011                     David A. Brown Middle       06
# 5730    060002707605                William Collier Elementary       06
# ...              ...                                       ...      ...
# 15979   069113512749                         Val Verde Academy       06
# 15980   069113513435                     El Potrero Pre-School       06
# 15981   069113513992                         Orange Vista High       06
# 100864  590010500138                Sherman Indian High School       59
# 100956  590019700136                               Noli School       59
#
#                      STREET           CITY STATE    ZIP STFIP   CNTY  \
# ...
